# %%
import pandas as pd

data2 = pd.read_csv("responses-2.csv")
data2.head()
# Out:
#                                   # What are you?  NONE  vegan  salmon  pig  \
# 0  phyvlis3ij6m0penvjphyvsfaqf9g2j9       SPONSER  NONE    NaN     NaN  NaN
# 1  tbcul4yc95vhgu4jtbcthc2wdgg05js2       CREATOR   NaN    NaN     NaN  NaN
# 2  bjf18ijy43jbufc2y5txtcbjf18ivvvu       SPONSER   NaN    NaN  salmon  NaN
# 3  iv4jxpcisshoopmiv4jxp7hg2dihl15v       SPONSER   NaN    NaN  salmon  NaN
# 4  85e0slvnljib2j5v8ypf85e0swz2jgh7       SPONSER   NaN  vegan  salmon  pig
#
#    cow +1 or +3  How likely is this +1/3 going to donate? Contact  \
# 0  NaN      NaN                                       NaN   email
# 1  NaN   '+none                                       NaN   email
# 2  cow      NaN                                       NaN   email
# 3  NaN      NaN                                       NaN   email
# 4  cow      NaN                                       NaN   email
#
#   Mobile Phone             Email number  Time is NOT money, NOT today.  \
# ...
