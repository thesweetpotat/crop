# %%
# Import modules only req.
# Delete unused modules (incl. only-from-module)

# %%
import pandas as pd
import numpy as np
import os
import math as m
# import sklearn

# %%
respath = os.path.join(os.getcwd(), "..", "data", "csv", "responses-4.csv")
responses = pd.read_csv(respath)
responses
# Out:
#                                   #  \
# 0  3okc8wdqtvksbiwp733okc8e1zg33nkp
# 1  9c3s80gtoiyaxwsnor6h9c3s801eqf6n
# 2  mxtzv7i6r0ryfwkow8dmxtzecas3ekyl
#
#   So, *which department* were you working in? And what was your *job title*?  \
# 0                                   Marketing                            BAE
# 1                                    Creative                            des
# 2                                     Product                            DOT
#
#   When did you *start* working here? Alright, and your final day is on…  \
# 0           2023-01-01T00:00:00.000Z           2023-01-31T00:00:00.000Z
# 1           2022-11-26T00:00:00.000Z           2023-07-31T00:00:00.000Z
# 2           2022-12-31T00:00:00.000Z           2023-03-13T00:00:00.000Z
#
#   Who was* your manager*?  Not satisfied with supervisor  Office politics  \
# 0                   Raaju  Not satisfied with supervisor  Office politics
# ...
